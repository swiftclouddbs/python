# %%
import os
import pandas as pd

# %%
#orders = pd.read_csv('/home/dba/python_dev/orders')

with open("/home/dba/python_dev/orders") as file:
  for item in file:
    print("For the souls trapped in the snare woven by " + item + "Hail Mary...\n")
# Out:
# For the souls trapped in the snare woven by Acacia
# Hail Mary...
#
# For the souls trapped in the snare woven by The Allied Degrees
# Hail Mary...
#
# For the souls trapped in the snare woven by The Red Cross of Constantine
# Hail Mary...
#
# For the souls trapped in the snare woven by Order of the Secret Monitor
# Hail Mary...
#
# For the souls trapped in the snare woven by Masonic Royal Order of Scotland
# Hail Mary...
#
# For the souls trapped in the snare woven by The Order of the Arrow
# Hail Mary...
#
# For the souls trapped in the snare woven by Prince Hall Freemasonry
# Hail Mary...
#
# For the souls trapped in the snare woven by Grand Orient Lodges
# Hail Mary...
#
# For the souls trapped in the snare woven by Mormonism
# Hail Mary...
#
# For the souls trapped in the snare woven by The Ancient Toltec Rite
# Hail Mary...
#
# For the souls trapped in the snare woven by The Order of Amaranth
# Hail Mary...
#
# ...
